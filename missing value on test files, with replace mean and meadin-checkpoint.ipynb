# %%
import pandas as pd
import numpy as np
import seaborn as  sns
import matplotlib.pyplot as plt

# %%
dataset_path = ("D:/Azeem Data/D Drive/kaggle/house price advance regression/train - Copy.csv")
df = pd.read_csv(dataset_path)

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
nul_col = df.isnull().sum()/ df.shape[0]*100

# %%
missing_col = nul_col[nul_col >20].keys()

# %%
missing_col
# Out:
# Index(['Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature'], dtype='object')

# %%
df2_drop_col = df.drop(columns=missing_col)
df2_drop_col.shape
# Out:
# (1460, 76)

# %%
df3_num = df2_drop_col.select_dtypes(include=['int64','float64'])
df3_num
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# 5        6          50         85.0    14115            5            5
# 6        7          20         75.0    10084            8            5
# 7        8          60          NaN    10382            7            6
# 8        9          50         51.0     6120            7            5
# 9       10         190         50.0     7420            5            6
# 10      11          20         70.0    11200            5            5
# 11      12          60         85.0    11924            9            5
# ...

# %%
plt.figure(figsize=(25,25))
sns.heatmap(df3_num.isnull())
# Out:
# <AxesSubplot:>

# %%
#that show the column where identify the mission value if any.
df3_num[df3_num.isnull().any(axis=1)]
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 7        8          60          NaN    10382            7            6
# 12      13          20          NaN    12968            5            6
# 14      15          20          NaN    10920            6            5
# 16      17          20          NaN    11241            6            7
# 24      25          20          NaN     8246            5            8
# 31      32          20          NaN     8544            5            6
# 39      40          90         65.0     6040            4            5
# 42      43          85          NaN     9180            5            7
# 43      44          20          NaN     9200            5            6
# 48      49         190         33.0     4456            4            5
# 50      51          60          NaN    13869            6            6
# 64      65          60          NaN     9375            7            5
# ...

# %%
df3_num.isnull().sum()/df3_num.shape[0]*100
# Out:
# Id                0.000000
# MSSubClass        0.000000
# LotFrontage      17.739726
# LotArea           0.000000
# OverallQual       0.000000
# OverallCond       0.000000
# YearBuilt         0.000000
# YearRemodAdd      0.000000
# MasVnrArea        0.547945
# BsmtFinSF1        0.000000
# BsmtFinSF2        0.000000
# BsmtUnfSF         0.000000
# TotalBsmtSF       0.000000
# 1stFlrSF          0.000000
# 2ndFlrSF          0.000000
# LowQualFinSF      0.000000
# GrLivArea         0.000000
# BsmtFullBath      0.000000
# BsmtHalfBath      0.000000
# FullBath          0.000000
# HalfBath          0.000000
# BedroomAbvGr      0.000000
# KitchenAbvGr      0.000000
# TotRmsAbvGrd      0.000000
# Fireplaces        0.000000
# GarageYrBlt       5.547945
# GarageCars        0.000000
# GarageArea        0.000000
# WoodDeckSF        0.000000
# OpenPorchSF       0.000000
# EnclosedPorch     0.000000
# 3SsnPorch         0.000000
# ScreenPorch       0.000000
# PoolArea          0.000000
# ...

# %%
#with loop we identify the columns name where mission value avaliable if any 
missing_num_val = [var for var in df3_num.columns if df3_num[var].isnull().sum()>0]
missing_num_val
# Out:
# ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']

# %%
#now before fill the missing value, we need to check either missing value fill by mean or median, use simple distribution

plt.figure(figsize=(10,10))
sns.set()
for i, var in enumerate(missing_num_val):
    plt.subplot(2,2,i+1)
    sns.distplot(df3_num[var],bins=20, kde_kws={'linewidth':5,'color':'red'})
# Out:
# C:\Users\Azeem Khan\AppData\Local\Temp\ipykernel_6800\3847708655.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df3_num[var],bins=20, kde_kws={'linewidth':5,'color':'red'})
# C:\Users\Azeem Khan\AppData\Local\Temp\ipykernel_6800\3847708655.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
df4_num_means = df3_num.fillna(df3_num.mean())

# %%
df4_num.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# LotFrontage      0
# LotArea          0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# MasVnrArea       0
# BsmtFinSF1       0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchenAbvGr     0
# TotRmsAbvGrd     0
# Fireplaces       0
# GarageYrBlt      0
# GarageCars       0
# GarageArea       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# MiscVal          0
# MoSold           0
# YrSold           0
# SalePrice        0
# dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.set()
for i, var in enumerate(missing_num_val):
    plt.subplot(2,2,i+1)
    sns.distplot(df3_num[var],bins=20,kde_kws= {'linewidth':2,'color':'Red'})
    sns.distplot(df4_num[var], bins=20,kde_kws= {'linewidth':2, 'color':"Green"})
    plt.legend()
# Out:
# C:\Users\Azeem Khan\AppData\Local\Temp\ipykernel_6800\2895702389.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df3_num[var],bins=20,kde_kws= {'linewidth':2,'color':'Red'})
# C:\Users\Azeem Khan\AppData\Local\Temp\ipykernel_6800\2895702389.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
df5_num_median = df3_num.fillna(df3_num.median())

# %%
plt.figure(figsize=(10,10))
sns.set()
for i, var in enumerate(missing_num_val):
    plt.subplot(2,2,i+1)
    sns.distplot(df3_num[var],bins=20,hist = False, kde_kws={'linewidth':2,'color':'Red'},label="Orignal")
    sns.distplot(df4_num_means[var],bins=20,hist = False, kde_kws={'linewidth':2,'color':'black'},label='Mean')
    sns.distplot(df5_num_median[var],bins=20,hist = False, kde_kws={'linewidth':2, 'color':'green'},label='Median')
    plt.legend()
# Out:
# C:\Users\Azeem Khan\AppData\Local\Temp\ipykernel_6800\3670343698.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df3_num[var],bins=20,hist = False, kde_kws={'linewidth':2,'color':'Red'},label="Orignal")
# C:\Users\Azeem Khan\AppData\Local\Temp\ipykernel_6800\3670343698.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
#identify outlier using boxplot

for i, var in enumerate(missing_num_val):
    plt.figure(figsize=(10,10))
    plt.subplot(3,1,1)
    sns.boxplot(df[var])
    plt.subplot(3,1,2)
    sns.boxplot(df4_num[var])
    plt.subplot(3,1,3)
    sns.boxplot(df5_num[var])

# %%
#CONCATENATE ROW WISE OF MISSING VALUES AMOUNT ORIGNAL, MEANS, AND MEDIAN
pd_concat = pd.concat([df3_num[missing_num_val],df4_num_means[missing_num_val],df5_num_median[missing_num_val]],axis=1)

# %%
#THAT SHOWN THE NULL VALUE IN ORIGNAL VALUE AS WELL AS MEANS AND MEDIAN
pd_concat[pd_concat.isnull().any(axis=1)]
# Out:
#       LotFrontage  MasVnrArea  GarageYrBlt  LotFrontage  MasVnrArea  \
# 7             NaN       240.0       1973.0    70.049958  240.000000
# 12            NaN         0.0       1962.0    70.049958    0.000000
# 14            NaN       212.0       1960.0    70.049958  212.000000
# 16            NaN       180.0       1970.0    70.049958  180.000000
# 24            NaN         0.0       1968.0    70.049958    0.000000
# 31            NaN         0.0       1966.0    70.049958    0.000000
# 39           65.0         0.0          NaN    65.000000    0.000000
# 42            NaN         0.0       1983.0    70.049958    0.000000
# 43            NaN         0.0       1977.0    70.049958    0.000000
# 48           33.0         0.0          NaN    33.000000    0.000000
# 50            NaN         0.0       1997.0    70.049958    0.000000
# 64            NaN       573.0       1998.0    70.049958  573.000000
# 66            NaN       287.0       1970.0    70.049958  287.000000
# ...
