# %%
url = "https://archive.ics.uci.edu/static/public/492/metro+interstate+traffic+volume.zip"

# %%
import requests

response = requests.get(url)

# %%
with open("Metro Interstate Traffic Volume.zip", "wb") as f:
    f.write(response.content)

# %%
import zipfile

# %%
with zipfile.ZipFile("Metro Interstate Traffic Volume.zip") as zipped:
    zipped.extractall("Metro Interstate Traffic Volume")

# %%
import pandas as pd

i_94 = pd.read_csv(r"D:\NED\uci machine learning\metro+interstate+traffic+volume\Metro_Interstate_Traffic_Volume.csv")

# %%
i_94.head()
# Out:
#   holiday    temp  rain_1h  snow_1h  clouds_all weather_main  \
# 0    None  288.28      0.0      0.0          40       Clouds
# 1    None  289.36      0.0      0.0          75       Clouds
# 2    None  289.58      0.0      0.0          90       Clouds
# 3    None  290.13      0.0      0.0          90       Clouds
# 4    None  291.14      0.0      0.0          75       Clouds
#
#   weather_description            date_time  traffic_volume
# 0    scattered clouds  2012-10-02 09:00:00            5545
# 1       broken clouds  2012-10-02 10:00:00            4516
# 2     overcast clouds  2012-10-02 11:00:00            4767
# 3     overcast clouds  2012-10-02 12:00:00            5026
# 4       broken clouds  2012-10-02 13:00:00            4918

# %%
i_94.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48204 entries, 0 to 48203
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   holiday              48204 non-null  object
#  1   temp                 48204 non-null  float64
#  2   rain_1h              48204 non-null  float64
#  3   snow_1h              48204 non-null  float64
#  4   clouds_all           48204 non-null  int64
#  5   weather_main         48204 non-null  object
#  6   weather_description  48204 non-null  object
#  7   date_time            48204 non-null  object
#  8   traffic_volume       48204 non-null  int64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 3.3+ MB

# %%
bol = i_94["holiday"].notnull()
bol
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 48199    True
# 48200    True
# 48201    True
# 48202    True
# 48203    True
# Name: holiday, Length: 48204, dtype: bool

# %%
i_94[bol]
# Out:
#       holiday    temp  rain_1h  snow_1h  clouds_all  weather_main  \
# 0        None  288.28      0.0      0.0          40        Clouds
# 1        None  289.36      0.0      0.0          75        Clouds
# 2        None  289.58      0.0      0.0          90        Clouds
# 3        None  290.13      0.0      0.0          90        Clouds
# 4        None  291.14      0.0      0.0          75        Clouds
# ...       ...     ...      ...      ...         ...           ...
# 48199    None  283.45      0.0      0.0          75        Clouds
# 48200    None  282.76      0.0      0.0          90        Clouds
# 48201    None  282.73      0.0      0.0          90  Thunderstorm
# 48202    None  282.09      0.0      0.0          90        Clouds
# 48203    None  282.12      0.0      0.0          90        Clouds
#
#           weather_description            date_time  traffic_volume
# 0            scattered clouds  2012-10-02 09:00:00            5545
# 1               broken clouds  2012-10-02 10:00:00            4516
# 2             overcast clouds  2012-10-02 11:00:00            4767
# 3             overcast clouds  2012-10-02 12:00:00            5026
# 4               broken clouds  2012-10-02 13:00:00            4918
# ...                       ...                  ...             ...
# 48199           broken clouds  2018-09-30 19:00:00            3543
# 48200         overcast clouds  2018-09-30 20:00:00            2781
# 48201  proximity thunderstorm  2018-09-30 21:00:00            2159
# 48202         overcast clouds  2018-09-30 22:00:00            1450
# 48203         overcast clouds  2018-09-30 23:00:00             954
#
# [48204 rows x 9 columns]

# %%
name = None

# %%
type(name)

# %%
name

# %%
"None"

"False"

# %%
bol1_null = i_94["holiday"].isnull()
bol1_null

# %%
i_94["holiday"][bol1_null]

# %%
48204-48143

# %%
i_94["holiday"][bol1_null] = "None"

# %%
i_94.head(49)
# Out:
#    holiday    temp  rain_1h  snow_1h  clouds_all weather_main  \
# 0     None  288.28      0.0      0.0          40       Clouds
# 1     None  289.36      0.0      0.0          75       Clouds
# 2     None  289.58      0.0      0.0          90       Clouds
# 3     None  290.13      0.0      0.0          90       Clouds
# 4     None  291.14      0.0      0.0          75       Clouds
# 5     None  291.72      0.0      0.0           1        Clear
# 6     None  293.17      0.0      0.0           1        Clear
# 7     None  293.86      0.0      0.0           1        Clear
# 8     None  294.14      0.0      0.0          20       Clouds
# 9     None  293.10      0.0      0.0          20       Clouds
# 10    None  290.97      0.0      0.0          20       Clouds
# 11    None  289.38      0.0      0.0           1        Clear
# 12    None  288.61      0.0      0.0           1        Clear
# 13    None  287.16      0.0      0.0           1        Clear
# 14    None  285.45      0.0      0.0           1        Clear
# 15    None  284.63      0.0      0.0           1        Clear
# 16    None  283.47      0.0      0.0           1        Clear
# 17    None  281.18      0.0      0.0           1        Clear
# 18    None  281.09      0.0      0.0           1        Clear
# 19    None  279.53      0.0      0.0           1        Clear
# 20    None  278.62      0.0      0.0           1        Clear
# 21    None  278.23      0.0      0.0           1        Clear
# 22    None  278.12      0.0      0.0           1        Clear
# 23    None  282.48      0.0      0.0           1        Clear
# 24    None  291.97      0.0      0.0           1        Clear
# 25    None  293.23      0.0      0.0           1        Clear
# 26    None  294.31      0.0      0.0           1        Clear
# 27    None  295.17      0.0      0.0           1        Clear
# 28    None  295.13      0.0      0.0           1        Clear
# 29    None  293.66      0.0      0.0          20       Clouds
# 30    None  290.65      0.0      0.0          20       Clouds
# 31    None  288.19      0.0      0.0          20       Clouds
# 32    None  287.10      0.0      0.0           1        Clear
# 33    None  286.25      0.0      0.0           1        Clear
# 34    None  285.26      0.0      0.0           1        Clear
# 35    None  284.55      0.0      0.0           1        Clear
# 36    None  283.47      0.0      0.0           1        Clear
# 37    None  283.17      0.0      0.0           1        Clear
# 38    None  282.04      0.0      0.0           1        Clear
# 39    None  281.69      0.0      0.0           1        Clear
# 40    None  281.32      0.0      0.0           1        Clear
# 41    None  280.74      0.0      0.0           1        Clear
# 42    None  280.57      0.0      0.0           1        Clear
# 43    None  281.86      0.0      0.0           1        Clear
# 44    None  284.98      0.0      0.0           1        Clear
# 45    None  289.18      0.0      0.0           1        Clear
# 46    None  291.55      0.0      0.0           1        Clear
# 47    None  294.97      0.0      0.0           1        Clear
# 48    None  296.38      0.0      0.0           1        Clear
#
#    weather_description            date_time  traffic_volume
# 0     scattered clouds  2012-10-02 09:00:00            5545
# 1        broken clouds  2012-10-02 10:00:00            4516
# 2      overcast clouds  2012-10-02 11:00:00            4767
# 3      overcast clouds  2012-10-02 12:00:00            5026
# 4        broken clouds  2012-10-02 13:00:00            4918
# 5         sky is clear  2012-10-02 14:00:00            5181
# 6         sky is clear  2012-10-02 15:00:00            5584
# 7         sky is clear  2012-10-02 16:00:00            6015
# 8           few clouds  2012-10-02 17:00:00            5791
# 9           few clouds  2012-10-02 18:00:00            4770
# 10          few clouds  2012-10-02 19:00:00            3539
# 11        sky is clear  2012-10-02 20:00:00            2784
# 12        sky is clear  2012-10-02 21:00:00            2361
# 13        sky is clear  2012-10-02 22:00:00            1529
# 14        sky is clear  2012-10-02 23:00:00             963
# 15        sky is clear  2012-10-03 00:00:00             506
# 16        sky is clear  2012-10-03 01:00:00             321
# 17        sky is clear  2012-10-03 02:00:00             273
# 18        sky is clear  2012-10-03 03:00:00             367
# 19        sky is clear  2012-10-03 04:00:00             814
# 20        sky is clear  2012-10-03 05:00:00            2718
# 21        sky is clear  2012-10-03 06:00:00            5673
# 22        sky is clear  2012-10-03 08:00:00            6511
# 23        sky is clear  2012-10-03 09:00:00            5471
# 24        sky is clear  2012-10-03 12:00:00            5097
# 25        sky is clear  2012-10-03 13:00:00            4887
# 26        sky is clear  2012-10-03 14:00:00            5337
# 27        sky is clear  2012-10-03 15:00:00            5692
# 28        sky is clear  2012-10-03 16:00:00            6137
# 29          few clouds  2012-10-03 18:00:00            4623
# 30          few clouds  2012-10-03 19:00:00            3591
# 31          few clouds  2012-10-03 20:00:00            2898
# 32        sky is clear  2012-10-03 21:00:00            2637
# 33        sky is clear  2012-10-03 22:00:00            1777
# 34        sky is clear  2012-10-03 23:00:00            1015
# 35        sky is clear  2012-10-04 00:00:00             598
# 36        sky is clear  2012-10-04 01:00:00             369
# 37        sky is clear  2012-10-04 02:00:00             312
# 38        sky is clear  2012-10-04 03:00:00             367
# 39        sky is clear  2012-10-04 04:00:00             835
# 40        sky is clear  2012-10-04 05:00:00            2726
# 41        sky is clear  2012-10-04 06:00:00            5689
# 42        sky is clear  2012-10-04 07:00:00            6990
# 43        sky is clear  2012-10-04 08:00:00            5985
# 44        sky is clear  2012-10-04 09:00:00            5309
# 45        sky is clear  2012-10-04 10:00:00            4603
# 46        sky is clear  2012-10-04 11:00:00            4884
# 47        sky is clear  2012-10-04 12:00:00            5104
# 48        sky is clear  2012-10-04 13:00:00            5178

# %%
i_94.info()

# %%
# i_94["holiday"].fillna("None")

# %%
i_94.head()

# %%
i_94.tail()

# %%
import matplotlib.pyplot as plt

# %%
i_94.traffic_volume.plot.hist()
plt.show()

# %%
i_94.traffic_volume.describe()
# Out:
# count    48204.000000
# mean      3259.818355
# std       1986.860670
# min          0.000000
# 25%       1193.000000
# 50%       3380.000000
# 75%       4933.000000
# max       7280.000000
# Name: traffic_volume, dtype: float64

# %% [markdown]
# * Day: 7AM to 7PM (12 hours)
# * Night: 7PM to 7AM (12 hours)

# %%
i_94.date_time = pd.to_datetime(i_94.date_time)

# %%
i_94.date_time.dtype
# Out:
# dtype('<M8[ns]')

# %%
i_94.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48204 entries, 0 to 48203
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   holiday              48204 non-null  object
#  1   temp                 48204 non-null  float64
#  2   rain_1h              48204 non-null  float64
#  3   snow_1h              48204 non-null  float64
#  4   clouds_all           48204 non-null  int64
#  5   weather_main         48204 non-null  object
#  6   weather_description  48204 non-null  object
#  7   date_time            48204 non-null  datetime64[ns]
#  8   traffic_volume       48204 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(2), object(3)
# memory usage: 3.3+ MB

# %%
i_94.date_time
# Out:
# 0       2012-10-02 09:00:00
# 1       2012-10-02 10:00:00
# 2       2012-10-02 11:00:00
# 3       2012-10-02 12:00:00
# 4       2012-10-02 13:00:00
#                 ...
# 48199   2018-09-30 19:00:00
# 48200   2018-09-30 20:00:00
# 48201   2018-09-30 21:00:00
# 48202   2018-09-30 22:00:00
# 48203   2018-09-30 23:00:00
# Name: date_time, Length: 48204, dtype: datetime64[ns]

# %%
day_bol = (i_94.date_time.dt.hour >= 7) & (i_94.date_time.dt.hour < 19)   # for OR | and for Not ~

# %%
day = i_94[day_bol]
day.sample(50)
# Out:
#       holiday     temp  rain_1h  snow_1h  clouds_all  weather_main  \
# 13418    None  276.790     2.10      0.0          75          Rain
# 41799    None  257.440     0.00      0.0           1          Haze
# 23200    None  282.160     0.42      0.0          90       Drizzle
# 2085     None  275.170     0.00      0.0          90          Rain
# 10467    None  254.440     0.00      0.0          64        Clouds
# 33245    None  276.080     0.00      0.0          90       Drizzle
# 471      None  282.710     0.00      0.0         100          Mist
# 3274     None  252.130     0.00      0.0          99        Clouds
# 19690    None  272.080     0.00      0.0          90          Mist
# 33171    None  279.270     0.00      0.0          75        Clouds
# 3891     None  273.780     0.00      0.0          75        Clouds
# 183      None  279.610     0.00      0.0          99       Drizzle
# 10058    None  272.150     0.00      0.0           1         Clear
# 28644    None  275.750     0.00      0.0          90       Drizzle
# 9508     None  284.770     0.00      0.0           0         Clear
# 39631    None  267.510     0.00      0.0          75        Clouds
# 19685    None  272.550     0.00      0.0          90          Snow
# 10978    None  262.070     0.00      0.0          64        Clouds
# 30662    None  275.950     0.00      0.0          90        Clouds
# 44659    None  292.430     0.00      0.0          40        Clouds
# 3709     None  270.450     0.00      0.0          75        Clouds
# 12652    None  254.270     0.00      0.0          90        Clouds
# 19084    None  296.460     0.00      0.0           1  Thunderstorm
# 38788    None  265.550     0.00      0.0          40          Snow
# 42032    None  274.650     0.00      0.0          90          Snow
# 29759    None  253.030     0.00      0.0           1         Clear
# 32328    None  281.150     0.00      0.0          90           Fog
# 39143    None  269.080     0.00      0.0          75          Snow
# 40165    None  260.450     0.00      0.0          90          Snow
# 37788    None  287.880     0.00      0.0          90  Thunderstorm
# 27092    None  289.360     0.00      0.0          64          Rain
# 27306    None  277.268     0.00      0.0           0         Clear
# 13867    None  279.760     0.00      0.0          90        Clouds
# 34905    None  291.080     0.00      0.0          90          Rain
# 40970    None  270.090     0.00      0.0          90          Mist
# 26231    None  285.160     0.00      0.0           1           Fog
# 19152    None  283.290     0.00      0.0          90          Rain
# 6370     None  290.410     0.00      0.0           5         Clear
# 5890     None  293.360     0.00      0.0          90          Rain
# 8858     None  305.250     0.00      0.0           0         Clear
# 33715    None  289.750     0.00      0.0          90          Rain
# 25533    None  296.480     0.00      0.0           0         Clear
# 17587    None  295.180     0.00      0.0          40        Clouds
# 43248    None  270.150     0.00      0.0          90          Snow
# 31635    None  262.650     0.00      0.0           1         Clear
# 7679     None  296.970     0.00      0.0           0         Clear
# 16173    None  295.560     0.00      0.0           1         Clear
# 32013    None  276.020     0.00      0.0          92          Mist
# 6863     None  290.160     0.00      0.0          92          Rain
# 37847    None  287.350     0.00      0.0          90       Drizzle
#
#                    weather_description           date_time  traffic_volume
# 13418                    moderate rain 2014-04-04 15:00:00            4811
# 41799                             haze 2018-02-24 08:00:00            3018
# 23200                          drizzle 2016-05-10 08:00:00            5878
# 2085                        light rain 2012-12-16 15:00:00            3884
# 10467                    broken clouds 2013-12-06 17:00:00            5672
# 33245                          drizzle 2017-05-01 08:00:00            5933
# 471                               mist 2012-10-20 12:00:00            4613
# 3274                   overcast clouds 2013-02-01 09:00:00            4996
# 19690                             mist 2015-11-26 14:00:00            3002
# 33171                    broken clouds 2017-04-29 10:00:00            4489
# 3891                     broken clouds 2013-02-25 15:00:00            5535
# 183            light intensity drizzle 2012-10-10 09:00:00            5680
# 10058                     sky is clear 2013-11-22 15:00:00            6047
# 28644          light intensity drizzle 2016-11-29 18:00:00            4017
# 9508                      Sky is Clear 2013-10-16 17:00:00            6344
# 39631                    broken clouds 2017-12-09 16:00:00            5160
# 19685                       light snow 2015-11-26 12:00:00            3232
# 10978                    broken clouds 2013-12-26 07:00:00            3861
# 30662                  overcast clouds 2017-01-31 12:00:00            4668
# 44659                 scattered clouds 2018-06-03 16:00:00            4547
# 3709                     broken clouds 2013-02-18 12:00:00            4680
# 12652                  overcast clouds 2014-03-03 10:00:00            4136
# 19084                     thunderstorm 2015-10-19 16:00:00            6414
# 38788                       light snow 2017-11-09 09:00:00            5710
# 42032                       light snow 2018-03-04 08:00:00            1840
# 29759                     sky is clear 2017-01-04 11:00:00            4358
# 32328                              fog 2017-04-03 09:00:00            4523
# 39143                       light snow 2017-11-21 11:00:00            4877
# 40165                       light snow 2017-12-28 15:00:00            4515
# 37788  thunderstorm with light drizzle 2017-10-06 14:00:00            5395
# 27092                       light rain 2016-10-04 11:00:00            4202
# 27306                     Sky is Clear 2016-10-13 11:00:00            4394
# 13867                  overcast clouds 2014-04-23 08:00:00            6279
# 34905             heavy intensity rain 2017-06-28 09:00:00            4930
# 40970                             mist 2018-01-25 18:00:00            4449
# 26231                              fog 2016-09-01 07:00:00            6066
# 19152             heavy intensity rain 2015-10-23 07:00:00            5776
# 6370                      sky is clear 2013-05-24 17:00:00            4896
# 5890                        light rain 2013-05-09 17:00:00            6305
# 8858                      Sky is Clear 2013-09-09 18:00:00            4652
# 33715                       light rain 2017-05-17 08:00:00            5822
# 25533                     Sky is Clear 2016-08-06 11:00:00            4826
# 17587                 scattered clouds 2015-08-20 18:00:00            4652
# 43248                             snow 2018-04-14 12:00:00            2147
# 31635                     sky is clear 2017-03-10 12:00:00            5614
# 7679                      Sky is Clear 2013-07-14 13:00:00            4438
# 16173                     sky is clear 2015-07-01 17:00:00            5969
# 32013                             mist 2017-03-24 07:00:00            6222
# 6863                        light rain 2013-06-10 17:00:00            6162
# 37847          light intensity drizzle 2017-10-07 13:00:00            4882

# %%
day.date_time.min()
# Out:
# Timestamp('2012-10-02 09:00:00')

# %%
day.date_time.max()
# Out:
# Timestamp('2018-09-30 18:00:00')

# %%
day.date_time.dt.time.min()
# Out:
# datetime.time(7, 0)

# %%
day.date_time.dt.time.max()
# Out:
# datetime.time(18, 0)

# %%
night_bol = (i_94.date_time.dt.hour >= 19) | (i_94.date_time.dt.hour < 7)
# 0 ,1,2,3,4,5,6, 19,20,21,22,23
# 12am,                      11pm

night = i_94[night_bol]

# %%
night.date_time.dt.time.max()
# Out:
# datetime.time(23, 0)

# %%
night.date_time.dt.time.min()
# Out:
# datetime.time(0, 0)

# %%
night.date_time.dt.hour.unique()

# %%
day.date_time.dt.hour.unique()

# %%
plt.subplot(1,2,1)
plt.hist(day["traffic_volume"])
plt.title("Traffic Volume : Day")

plt.subplot(1,2,2)
plt.hist(night["traffic_volume"])
plt.title("Traffic Volume : Nigth")

plt.show()

# %%
plt.figure(figsize= (11, 4))
plt.subplot(1,2,1)
plt.hist(day["traffic_volume"])
plt.title("Traffic Volume : Day")

plt.subplot(1,2,2)
plt.hist(night["traffic_volume"])
plt.title("Traffic Volume : Night")

plt.show()

# %%
plt.figure(figsize= (11, 4))
plt.subplot(1,2,1)
plt.hist(day["traffic_volume"])
plt.title("Traffic Volume : Day")
plt.xlim(0,8000)
plt.ylim(0,8000)

plt.subplot(1,2,2)
plt.hist(night["traffic_volume"])
plt.title("Traffic Volume : Night")
plt.xlim(0,8000)
plt.ylim(0,8000)

plt.show()

# %%
day_description = day.traffic_volume.describe()
day_description
# Out:
# count    23877.000000
# mean      4762.047452
# std       1174.546482
# min          0.000000
# 25%       4252.000000
# 50%       4820.000000
# 75%       5559.000000
# max       7280.000000
# Name: traffic_volume, dtype: float64

# %%
night_description = night.traffic_volume.describe()
night_description
# Out:
# count    24327.000000
# mean      1785.377441
# std       1441.951197
# min          0.000000
# 25%        530.000000
# 50%       1287.000000
# 75%       2819.000000
# max       6386.000000
# Name: traffic_volume, dtype: float64

# %%
day_night_descript = pd.DataFrame(day_description)

# %%
day_night_descript.columns
# Out:
# Index(['traffic_volume'], dtype='object')

# %%
day_night_descript.columns = ["Day"]

# %%
day_night_descript
# Out:
#                 Day
# count  23877.000000
# mean    4762.047452
# std     1174.546482
# min        0.000000
# 25%     4252.000000
# 50%     4820.000000
# 75%     5559.000000
# max     7280.000000

# %%
day_night_descript["Night"] = night_description

# %%
plt.figure(figsize= (11, 4))
plt.subplot(1,2,1)
plt.hist(day["traffic_volume"])
plt.title("Traffic Volume : Day")
plt.xlim(0,8000)
plt.ylim(0,8000)
plt.xlabel("Traffic Volume")
plt.ylabel("No.of Incident")

plt.subplot(1,2,2)
plt.hist(night["traffic_volume"])
plt.title("Traffic Volume : Night")
plt.xlim(0,8000)
plt.ylim(0,8000)
plt.xlabel("Traffic Volume")


plt.show()

# %%
day_night_descript
# Out:
#                 Day         Night
# count  23877.000000  24327.000000
# mean    4762.047452   1785.377441
# std     1174.546482   1441.951197
# min        0.000000      0.000000
# 25%     4252.000000    530.000000
# 50%     4820.000000   1287.000000
# 75%     5559.000000   2819.000000
# max     7280.000000   6386.000000

# %%
night.shape
# Out:
# (24327, 9)

# %%
night.traffic_volume.value_counts(bins = 10).sort_index()
# Out:
# (-6.3870000000000005, 638.6]    7153
# (638.6, 1277.2]                 4983
# (1277.2, 1915.8]                1950
# (1915.8, 2554.4]                2350
# (2554.4, 3193.0]                4359
# (3193.0, 3831.6]                1872
# (3831.6, 4470.2]                 256
# (4470.2, 5108.8]                 150
# (5108.8, 5747.4]                 821
# (5747.4, 6386.0]                 433
# Name: traffic_volume, dtype: int64

# %% [markdown]
# # Time indicators
#
# * Month,
# * Day of Week,
# * Time of Day

# %%
day
# Out:
#       holiday    temp  rain_1h  snow_1h  clouds_all weather_main  \
# 0        None  288.28     0.00      0.0          40       Clouds
# 1        None  289.36     0.00      0.0          75       Clouds
# 2        None  289.58     0.00      0.0          90       Clouds
# 3        None  290.13     0.00      0.0          90       Clouds
# 4        None  291.14     0.00      0.0          75       Clouds
# ...       ...     ...      ...      ...         ...          ...
# 48194    None  283.84     0.00      0.0          75         Rain
# 48195    None  283.84     0.00      0.0          75      Drizzle
# 48196    None  284.38     0.00      0.0          75         Rain
# 48197    None  284.79     0.00      0.0          75       Clouds
# 48198    None  284.20     0.25      0.0          75         Rain
#
#            weather_description           date_time  traffic_volume
# 0             scattered clouds 2012-10-02 09:00:00            5545
# 1                broken clouds 2012-10-02 10:00:00            4516
# 2              overcast clouds 2012-10-02 11:00:00            4767
# 3              overcast clouds 2012-10-02 12:00:00            5026
# 4                broken clouds 2012-10-02 13:00:00            4918
# ...                        ...                 ...             ...
# 48194    proximity shower rain 2018-09-30 15:00:00            4302
# 48195  light intensity drizzle 2018-09-30 15:00:00            4302
# 48196               light rain 2018-09-30 16:00:00            4283
# 48197            broken clouds 2018-09-30 17:00:00            4132
# 48198               light rain 2018-09-30 18:00:00            3947
#
# [23877 rows x 9 columns]

# %%
day.date_time.dt.month
# Out:
# 0        10
# 1        10
# 2        10
# 3        10
# 4        10
#          ..
# 48194     9
# 48195     9
# 48196     9
# 48197     9
# 48198     9
# Name: date_time, Length: 23877, dtype: int64

# %%
day["month"] = day.date_time.dt.month
# Out:
# C:\Users\Azeem Khan\AppData\Local\Temp\ipykernel_19988\1119384693.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day["month"] = day.date_time.dt.month

# %%
day
# Out:
#       holiday    temp  rain_1h  snow_1h  clouds_all weather_main  \
# 0        None  288.28     0.00      0.0          40       Clouds
# 1        None  289.36     0.00      0.0          75       Clouds
# 2        None  289.58     0.00      0.0          90       Clouds
# 3        None  290.13     0.00      0.0          90       Clouds
# 4        None  291.14     0.00      0.0          75       Clouds
# ...       ...     ...      ...      ...         ...          ...
# 48194    None  283.84     0.00      0.0          75         Rain
# 48195    None  283.84     0.00      0.0          75      Drizzle
# 48196    None  284.38     0.00      0.0          75         Rain
# 48197    None  284.79     0.00      0.0          75       Clouds
# 48198    None  284.20     0.25      0.0          75         Rain
#
#            weather_description           date_time  traffic_volume  month
# 0             scattered clouds 2012-10-02 09:00:00            5545     10
# 1                broken clouds 2012-10-02 10:00:00            4516     10
# 2              overcast clouds 2012-10-02 11:00:00            4767     10
# 3              overcast clouds 2012-10-02 12:00:00            5026     10
# 4                broken clouds 2012-10-02 13:00:00            4918     10
# ...                        ...                 ...             ...    ...
# 48194    proximity shower rain 2018-09-30 15:00:00            4302      9
# 48195  light intensity drizzle 2018-09-30 15:00:00            4302      9
# 48196               light rain 2018-09-30 16:00:00            4283      9
# 48197            broken clouds 2018-09-30 17:00:00            4132      9
# 48198               light rain 2018-09-30 18:00:00            3947      9
#
# [23877 rows x 10 columns]

# %%
day.date_time.dt.strftime("%B")
# Out:
# 0          October
# 1          October
# 2          October
# 3          October
# 4          October
#            ...
# 48194    September
# 48195    September
# 48196    September
# 48197    September
# 48198    September
# Name: date_time, Length: 23877, dtype: object

# %%
day["month_name"]= day.date_time.dt.strftime("%B")
# Out:
# C:\Users\Azeem Khan\AppData\Local\Temp\ipykernel_19988\627334189.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day["month_name"]= day.date_time.dt.strftime("%B")

# %%
day

# %%
groups = day.groupby("month_name")
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x0000019E49613490>

# %%
groups["traffic_volume"].mean()
# Out:
# month_name
# April        4906.894305
# August       4928.302035
# December     4374.834566
# February     4711.198394
# January      4495.613727
# July         4595.035744
# June         4898.019566
# March        4889.409560
# May          4911.121609
# November     4704.094319
# October      4921.234922
# September    4870.783145
# Name: traffic_volume, dtype: float64

# %%
groups = day.groupby("month")
by_month = groups["traffic_volume"].mean()
by_month
# Out:
# month
# 1     4495.613727
# 2     4711.198394
# 3     4889.409560
# 4     4906.894305
# 5     4911.121609
# 6     4898.019566
# 7     4595.035744
# 8     4928.302035
# 9     4870.783145
# 10    4921.234922
# 11    4704.094319
# 12    4374.834566
# Name: traffic_volume, dtype: float64

# %%
by_month.plot.line()
plt.show()

# %%
day.date_time.dt.year
# Out:
# 0        2012
# 1        2012
# 2        2012
# 3        2012
# 4        2012
#          ...
# 48194    2018
# 48195    2018
# 48196    2018
# 48197    2018
# 48198    2018
# Name: date_time, Length: 23877, dtype: int64

# %%
day["year"] = day.date_time.dt.year
# Out:
# C:\Users\Azeem Khan\AppData\Local\Temp\ipykernel_19988\3951727864.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day["year"] = day.date_time.dt.year

# %%
day

# %%
only_july = day[day["month"] == 7]

only_july
# Out:
#       holiday    temp  rain_1h  snow_1h  clouds_all weather_main  \
# 7350     None  289.15      0.0      0.0          75       Clouds
# 7351     None  291.59      0.0      0.0           1        Clear
# 7352     None  294.15      0.0      0.0           1        Clear
# 7353     None  295.60      0.0      0.0           1        Clear
# 7354     None  297.15      0.0      0.0           1        Clear
# ...       ...     ...      ...      ...         ...          ...
# 46313    None  301.29      0.0      0.0          20       Clouds
# 46314    None  301.43      0.0      0.0          40       Clouds
# 46315    None  302.00      0.0      0.0          40       Clouds
# 46316    None  302.29      0.0      0.0          20       Clouds
# 46317    None  301.93      0.0      0.0          20       Clouds
#
#       weather_description           date_time  traffic_volume  month  \
# 7350        broken clouds 2013-07-01 07:00:00            6783      7
# 7351         sky is clear 2013-07-01 08:00:00            5742      7
# 7352         sky is clear 2013-07-01 09:00:00            4764      7
# 7353         sky is clear 2013-07-01 10:00:00            4669      7
# 7354         sky is clear 2013-07-01 11:00:00            4863      7
# ...                   ...                 ...             ...    ...
# 46313          few clouds 2018-07-31 14:00:00            4922      7
# 46314    scattered clouds 2018-07-31 15:00:00            5722      7
# 46315    scattered clouds 2018-07-31 16:00:00            6357      7
# 46316          few clouds 2018-07-31 17:00:00            5912      7
# 46317          few clouds 2018-07-31 18:00:00            4740      7
#
#       month_name  year
# 7350        July  2013
# 7351        July  2013
# 7352        July  2013
# 7353        July  2013
# 7354        July  2013
# ...          ...   ...
# 46313       July  2018
# 46314       July  2018
# 46315       July  2018
# 46316       July  2018
# 46317       July  2018
#
# [2378 rows x 12 columns]

# %%
only_july.groupby("year")["traffic_volume"].mean()
# Out:
# year
# 2013    4914.354054
# 2014    4871.598240
# 2015    4613.146226
# 2016    3924.923645
# 2017    4734.120301
# 2018    4586.899543
# Name: traffic_volume, dtype: float64

# %%
only_july.groupby("year")["traffic_volume"].mean().plot.line()
plt.show()

# %%
i_94['dayofweek'] = i_94.date
