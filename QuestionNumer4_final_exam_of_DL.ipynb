# %% [markdown]
# <a href="https://colab.research.google.com/github/azimhims/azimhims/blob/main/QuestionNumer4_final_exam_of_DL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.layers import Input, Dense, Concatenate
from tensorflow.keras.models import Model

# Define Input layers
input_1 = Input(shape=(128,), name="Input_1")
input_2 = Input(shape=(128,), name="Input_2")

# Dense layers for the first input
dense_1 = Dense(64, activation='relu', name="Dense_1")(input_1)
dense_2 = Dense(32, activation='relu', name="Dense_2")(dense_1)
dense_3 = Dense(4, activation='relu', name="Dense_3")(dense_2)

# dense_1 = Dense(64, activation='relu', name="Dense_1")(input_1)
# dense_2 = Dense(32, activation='relu', name="Dense_2")(dense_1)

# Dense layers for the second input
dense_3 = Dense(64, activation='relu', name="Dense_3")(input_2)
dense_4 = Dense(32, activation='relu', name="Dense_4")(dense_3)


dense_5 = Dense(4, activation='relu', name="Dense_5")(dense_2)
dense_6 = Dense(4, activation='relu', name="Dense_6")(dense_4)


concat = Concatenate(name="Concatenate")([dense_5, dense_6])

# Additional Dense layers after concatenation
dense_7 = Dense(8, activation='relu', name="Dense_7")(concat)
#dense_8 = Dense(2, activation='relu', name="Dense_8")(dense_7)

# Final output layer
output = Dense(1, activation='sigmoid', name="Output")(dense_7)

# Create the model
model = Model(inputs=[input_1, input_2], outputs=output)

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Summary of the model
model.summary()
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Input_1 (InputLayer)      │ (None, 128)            │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Input_2 (InputLayer)      │ (None, 128)            │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Dense_1 (Dense)           │ (None, 64)             │          8,256 │ Input_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# ...

# %%
#i want to check in pipline like
from keras.utils import plot_model
plot_model(model)
